# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\vikil\Desktop\ML\data_Sets\netflix_titles.csv')
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
a=data.groupby('type')
Movie_list=a.get_group('Movie')
tv_show=a.get_group('TV Show')

# %%
b=data.groupby('rating')
tvy=b.get_group('TV-Y')
tvy7=b.get_group('TV-Y7')
tvg=b.get_group('TV-G')
tvpg=b.get_group('TV-PG')
tv14=b.get_group('TV-14')
tvma=b.get_group('TV-MA')
g=b.get_group('G')
nc17=b.get_group('NC-17')
nr=b.get_group('NR')
pg=b.get_group('PG')
pg13=b.get_group('PG-13')
r=b.get_group('R')
tvy7fv=b.get_group('TV-Y7-FV')
ur=b.get_group('UR')

# %%
content='MOVIES','TV SHOWS'
num=[4265,1969]
ex=(0,0)
plt.pie(num,explode=ex,labels=content,autopct='%1.2f%%')
plt.show()

# %%
content='TV-Y','TV-Y7','TV-G','TV-PG','TV-14','TV-MA','G','NC-17','NR','PG','PG-13','R','TV-Y7-FV','UR','OTHERS'
num=[143,169,149,701,1698,2027,37,2,218,184,286,508,95,7,10]
plt.pie(num,labels=content,autopct='%0.2f%%',radius=2)
plt.show()

# %%
x=data['title']
y=data['release_year']
plt.xlabel('release year')
plt.ylabel('title')
plt.scatter(x,y)
plt.show()
